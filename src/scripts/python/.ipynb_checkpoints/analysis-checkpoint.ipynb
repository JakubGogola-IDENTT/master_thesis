# %%
# %config IPCompleter.greedy=True

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
solvers = ['Chuffed', 'CPOptimizer', 'OR-Tools', 'Gecode']

# %%
summary_sync = pd.read_csv('summary_sync.csv')
summary_sync
# Out:
#          solver  size  max_objective  steps  solve_time  variables
# 0       Chuffed     5             86     11      0.0000          0
# 1       Chuffed    10            256      8      0.0000          0
# 2       Chuffed    15            366      2      0.0000          0
# 3       Chuffed    19            653      4      0.0000          0
# 4       Chuffed    23              0      0      0.0000          0
# 5   CPOptimizer     5             88     20     57.9700         10
# 6   CPOptimizer    10            316     50     56.7400         44
# 7   CPOptimizer    15            363      3     55.9800         84
# 8   CPOptimizer    19            698     52     55.5800        126
# 9   CPOptimizer    23              0      0     51.7400        156
# 10       Gecode     5             72     14     58.3524         61
# 11       Gecode    10            210     21     57.0124        245
# 12       Gecode    15            385     21     55.9418        535
# 13       Gecode    19            570     18     55.6006        849
# 14       Gecode    23            842      9      0.0000          0
# 15     OR-Tools     5              0      0      0.0000          0
# 16     OR-Tools    10              0      0      0.0000          0
# 17     OR-Tools    15              0      0      0.0000          0
# 18     OR-Tools    19              0      0      0.0000          0
# 19     OR-Tools    23              0      0      0.0000          0

# %%
summary_parallel = pd.read_csv('summary_parallel.csv')
summary_parallel
# Out:
#          solver  size  max_objective  steps  solve_time  variables
# 0       Chuffed     5             82     15     58.4023         61
# 1       Chuffed    10            225     17     58.0607        245
# 2       Chuffed    15            394     22     56.9169        535
# 3       Chuffed    19            596     24     56.8783        849
# 4       Chuffed    23            813     11      0.0000          0
# 5   CPOptimizer     5             78     19     58.1488         61
# 6   CPOptimizer    10            222     24     57.6964        245
# 7   CPOptimizer    15            392     19     56.8768        535
# 8   CPOptimizer    19            574     20     56.9341        849
# 9   CPOptimizer    23            809      4      0.0000          0
# 10       Gecode     5             77     17     58.2278         61
# 11       Gecode    10            225     20     57.8795        245
# 12       Gecode    15            392     20     56.7171        535
# 13       Gecode    19            599     15     56.8204        849
# 14       Gecode    23            820      5      0.0000          0
# 15     OR-Tools     5             76     15     58.3039         61
# 16     OR-Tools    10            227     17     57.9489        245
# 17     OR-Tools    15            400     27     56.7719        535
# 18     OR-Tools    19            563     14     56.8399        849
# 19     OR-Tools    23            828     14      0.0000          0

# %%
ss = summary_sync.groupby('solver')
ss.get_group('Chuffed')
# Out:
#     solver  size  max_objective  steps  solve_time  variables
# 0  Chuffed     5             86     11         0.0          0
# 1  Chuffed    10            256      8         0.0          0
# 2  Chuffed    15            366      2         0.0          0
# 3  Chuffed    19            653      4         0.0          0
# 4  Chuffed    23              0      0         0.0          0

# %%
x = np.linspace(1, 1000, 20)
fig, ax = plt.subplots(figsize=(15,10))
ax.plot(x, summary_sync['steps'])
